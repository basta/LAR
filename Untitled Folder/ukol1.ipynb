# %%
from robolab_turtlebot import Turtlebot, Rate, get_time
import numpy as np
from robolab_turtlebot import Turtlebot, Rate

import cv2
from PIL import Image

turtle = Turtlebot(rgb=True, depth=True, pc=True)
rate = Rate(40)


def strip(img, start=120, stop=170):
    return img[start:stop, :]


def calculate_access_point(gate1, gate2, offset, closer_point):
    difference = (gate1 - gate2) / 2
    middle = difference + gate2
    perpendicular_v = np.array([-difference[1], difference[0]])
    perpendicular_v /= np.linalg.norm(perpendicular_v)
    point1 = middle + offset * perpendicular_v
    point2 = middle + offset * perpendicular_v * -1
    if np.linalg.norm(point1 - closer_point) < np.linalg.norm(point2 - closer_point):
        return point1
    else:
        return point2


def move_to(x, y):
    v = turtle.get_odometry()
    dx = x - v[0]
    dy = y - v[1]
    dphi = math.atan2(dy, dx) - v[2]
    lenght = ((dy**2+dx**2)**(1/2))
    movement = np.array([lenght, dphi])
    return movement


def pohni_pyco(movement):
    final_phi = movement[1]
    lenght = movement[0]
    finish_rotation = False
    finish_position = False

    while not finish_rotation:
        current_place = turtle.get_odometry()
        t = get_time()
        #x = current_place[0]
        #y = current_place[1]
        phi = current_place[2]
        print(phi)
        diff_phi = abs(phi - final_phi)
        if diff_phi < 0.05:
            finish_rotation = True
        else:
            turtle.cmd_velocity(angular=1)
            rate.sleep()
        print("Dp", diff_phi)
    turtle.cmd_velocity(angular=0)

    time.sleep(1)

    while not finish_position:
        current_place = turtle.get_odometry()
        t = get_time()
        x = current_place[0]
        y = current_place[1]
        #phi = current_place[2]
        new_lenght = (y**2+x**2)**(1/2)
        if new_lenght > lenght:
            finish_position = True
        else:
            turtle.cmd_velocity(linear=0.1)
            rate.sleep()


def flatten(img):
    row = strip(img)
    row[:, :, 0] = np.mean(row[:, :, 0], axis=0)
    row[:, :, 1] = np.mean(row[:, :, 1], axis=0)
    row[:, :, 2] = np.mean(row[:, :, 2], axis=0)
    return row


def get_gates(min_width=5):
    img = turtle.get_rgb_image()
    permute_rgb(img)
    mask = get_garage_mask(img)
    return [gate for gate in largest_area(mask[0]) if gate[2] > min_width][:2]


def permute_rgb(img):
    img[:, :, [0, 1, 2]] = img[:, :, [2, 1, 0]]

def get_garage_mask(img):
    img_strip = flatten(img)
    hsv = cv2.cvtColor(img_strip, cv2.COLOR_RGB2HSV)
    # PURPLE
    lower_color = np.array([115, 0, 0])
    upper_color = np.array([140, 250, 250])
    mask = cv2.inRange(hsv, lower_color, upper_color)
    mask = mask / np.max(mask)
    return mask


def largest_area(arr):
    starts = []
    ends = []
    state = "BLACK"
    for i, n in enumerate(arr):
        if n == 1 and state == "BLACK":
            state = "WHITE"
            starts.append(i)
        elif n == 0 and state == "WHITE":
            state = "BLACK"
            ends.append(i)

    if state == "WHITE":
        ends.append(i + 1)

    ret = []
    for start, end in zip(starts, ends):
        ret.append((start, end, end - start))

    return sorted(ret, reverse=True, key=lambda x: x[2])

# %%
gates = get_gates()
gate1_x = int((gates[0][0] + gates[0][0]) / 2)
gate2_x = int((gates[1][0] + gates[1][0]) / 2)

pcl = turtle.get_point_cloud()
print(pcl[140][gate1_x])


def get_gate_coords():
    gates = get_gates()
    gate1_x = int((gates[0][0] + gates[0][0]) / 2)
    gate2_x = int((gates[1][0] + gates[1][0]) / 2)

    pcl = turtle.get_point_cloud()
    C = 3
    return [
        np.array(
            [
                -1*(pcl[140][gate1_x][1] - 0.2),
                pcl[140][gate1_x][0]
            ]
        )*C,
        np.array(
            [
                -1*(pcl[140][gate2_x][1] - 0.2),
                pcl[140][gate2_x][0]
            ]
        )*C
    ]
# Out:
# [ 0.35101151 -0.1417667   0.92400002]

# %%
import math
import time


def rotate_until_see():
    while len(get_gates()) != 2:
        turtle.cmd_velocity(angular=0.314)
        rate.sleep()

print("PHASE ONE")
rotate_until_see()
coords = get_gate_coords()

turtle.reset_odometry()
time.sleep(1)
ap = calculate_access_point(coords[0], coords[1], 1, [0, 0])
dap = move_to(ap[0], ap[1])
print("Move to:", dap)
pohni_pyco(dap)

print("PHASE TWO")

turtle.reset_odometry()
time.sleep(1)

rotate_until_see()
coords = get_gate_coords()
ap = calculate_access_point(coords[0], coords[1], 0.2, [100, 0])
dap = move_to(ap[0], ap[1])
print("Move to:", dap)
pohni_pyco(dap)

# %%
import matplotlib.pyplot as plt
plt.imshow(np.linalg.norm(turtle.get_point_cloud(), axis=2))

# %%
plt.imshow(get_garage_mask(turtle.get_rgb_image()))

# %%
img = turtle.get_rgb_image()
permute_rgb(img)
plt.imshow(img)

# %%
for _ in range(4):
    turtle.reset_odometry()
    time.sleep(0.5)
    pohni_pyco([1, math.pi / 2])

# %%
from IPython.display import clear_output
import matplotlib.pyplot as plt
import time
def visualise(circles, image_f, xlim=None, ylim=None):
    clear_output(wait=True)
    fig = plt.figure()
    ax = fig.add_axes([0, 0, 1, 1])
    ax.set_xlim(xlim)
    ax.set_ylim(ylim)

    if image_f:
        ax.imshow(image_f())

    for circle in circles:
        ax.add_patch(circle)

    plt.show()
    time.sleep(1/30)

    if image_f:
        ax.imshow(image_f())

    for circle in circles:
        ax.add_patch(circle)

    plt.show()
    time.sleep(1/30)



x = 0
while True:
    x += 50
    visualise([plt.Circle([], 30, color='r')], None, [-1000, 1000], [-1000, 1000])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 34
#      32 while True:
#      33     x += 50
# ---> 34     visualise([plt.Circle([10, x], 30, color='r')], None, [-1000, 1000], [-1000, 1000])
#
# Cell In[15], line 17, in visualise(circles, image_f, xlim, ylim)
#      14 for circle in circles:
#      15     ax.add_patch(circle)
# ---> 17 plt.show()
#      18 time.sleep(1/30)
#      20 if image_f:
#
# File /usr/lib/python3/dist-packages/matplotlib/pyplot.py:269, in show(*args, **kw)
#     252 """
#     253 Display a figure.
#     254
#    (...)
#     266 described above.
#     267 """
#     268 global _show
# --> 269 return _show(*args, **kw)
#
# File ~/.local/lib/python3.8/site-packages/matplotlib_inline/backend_inline.py:90, in show(close, block)
#      88 try:
#      89     for figure_manager in Gcf.get_all_fig_managers():
# ---> 90         display(
#      91             figure_manager.canvas.figure,
#      92             metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      93         )
#      94 finally:
#      95     show._to_draw = []
#
# File ~/.local/lib/python3.8/site-packages/IPython/core/display_functions.py:298, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     296     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     297 else:
# --> 298     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     299     if not format_dict:
#     300         # nothing to display (e.g. _ipython_display_ took over)
#     301         continue
#
# File ~/.local/lib/python3.8/site-packages/IPython/core/formatters.py:177, in DisplayFormatter.format(self, obj, include, exclude)
#     175 md = None
#     176 try:
# --> 177     data = formatter(obj)
#     178 except:
#     179     # FIXME: log the exception
#     180     raise
#
# File <decorator-gen-2>:2, in __call__(self, obj)
#
# File ~/.local/lib/python3.8/site-packages/IPython/core/formatters.py:221, in catch_format_error(method, self, *args, **kwargs)
#     219 """show traceback on failed format call"""
#     220 try:
# --> 221     r = method(self, *args, **kwargs)
#     222 except NotImplementedError:
#     223     # don't warn on NotImplementedErrors
#     224     return self._check_return(None, args[0])
#
# File ~/.local/lib/python3.8/site-packages/IPython/core/formatters.py:338, in BaseFormatter.__call__(self, obj)
#     336     pass
#     337 else:
# --> 338     return printer(obj)
#     339 # Finally look for special method names
#     340 method = get_real_method(obj, self.print_method)
#
# File ~/.local/lib/python3.8/site-packages/IPython/core/pylabtools.py:152, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149     from matplotlib.backend_bases import FigureCanvasBase
#     150     FigureCanvasBase(fig)
# --> 152 fig.canvas.print_figure(bytes_io, **kw)
#     153 data = bytes_io.getvalue()
#     154 if fmt == 'svg':
#
# File /usr/lib/python3/dist-packages/matplotlib/backend_bases.py:2056, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2050 if bbox_inches:
#    2051     # call adjust_bbox to save only the given area
#    2052     if bbox_inches == "tight":
#    2053         # When bbox_inches == "tight", it saves the figure twice.
#    2054         # The first save command (to a BytesIO) is just to estimate
#    2055         # the bounding box of the figure.
# -> 2056         result = print_method(
#    2057             io.BytesIO(),
#    2058             dpi=dpi,
#    2059             facecolor=facecolor,
#    2060             edgecolor=edgecolor,
#    2061             orientation=orientation,
#    2062             dryrun=True,
#    2063             **kwargs)
#    2064         renderer = self.figure._cachedRenderer
#    2065         bbox_artists = kwargs.pop("bbox_extra_artists", None)
#
# File /usr/lib/python3/dist-packages/matplotlib/backends/backend_agg.py:527, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     523     (Image.frombuffer("RGBA", size, buf, "raw", "RGBA", 0, 1)
#     524      .save(filename_or_obj, format="png", **pil_kwargs))
#     526 else:
# --> 527     FigureCanvasAgg.draw(self)
#     528     renderer = self.get_renderer()
#     529     with cbook._setattr_cm(renderer, dpi=self.figure.dpi), \
#     530             cbook.open_file_cm(filename_or_obj, "wb") as fh:
#
# File /usr/lib/python3/dist-packages/matplotlib/backends/backend_agg.py:388, in FigureCanvasAgg.draw(self)
#     386 self.renderer = self.get_renderer(cleared=True)
#     387 with RendererAgg.lock:
# --> 388     self.figure.draw(self.renderer)
#     389     # A GUI class may be need to update a window using this draw, so
#     390     # don't forget to call the superclass.
#     391     super().draw()
#
# File /usr/lib/python3/dist-packages/matplotlib/artist.py:38, in allow_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      35     if artist.get_agg_filter() is not None:
#      36         renderer.start_filter()
# ---> 38     return draw(artist, renderer, *args, **kwargs)
#      39 finally:
#      40     if artist.get_agg_filter() is not None:
#
# File /usr/lib/python3/dist-packages/matplotlib/figure.py:1708, in Figure.draw(self, renderer)
#    1705             # ValueError can occur when resizing a window.
#    1707     self.patch.draw(renderer)
# -> 1708     mimage._draw_list_compositing_images(
#    1709         renderer, self, artists, self.suppressComposite)
#    1711     renderer.close_group('figure')
#    1712 finally:
#
# File /usr/lib/python3/dist-packages/matplotlib/image.py:135, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133 if not_composite or not has_images:
#     134     for a in artists:
# --> 135         a.draw(renderer)
#     136 else:
#     137     # Composite any adjacent images together
#     138     image_group = []
#
# File /usr/lib/python3/dist-packages/matplotlib/artist.py:38, in allow_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      35     if artist.get_agg_filter() is not None:
#      36         renderer.start_filter()
# ---> 38     return draw(artist, renderer, *args, **kwargs)
#      39 finally:
#      40     if artist.get_agg_filter() is not None:
#
# File /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:2647, in _AxesBase.draw(self, renderer, inframe)
#    2644         a.draw(renderer)
#    2645     renderer.stop_rasterizing()
# -> 2647 mimage._draw_list_compositing_images(renderer, self, artists)
#    2649 renderer.close_group('axes')
#    2650 self.stale = False
#
# File /usr/lib/python3/dist-packages/matplotlib/image.py:135, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133 if not_composite or not has_images:
#     134     for a in artists:
# --> 135         a.draw(renderer)
#     136 else:
#     137     # Composite any adjacent images together
#     138     image_group = []
#
# File /usr/lib/python3/dist-packages/matplotlib/artist.py:38, in allow_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      35     if artist.get_agg_filter() is not None:
#      36         renderer.start_filter()
# ---> 38     return draw(artist, renderer, *args, **kwargs)
#      39 finally:
#      40     if artist.get_agg_filter() is not None:
#
# File /usr/lib/python3/dist-packages/matplotlib/axis.py:1203, in Axis.draw(self, renderer, *args, **kwargs)
#    1200     return
#    1201 renderer.open_group(__name__)
# -> 1203 ticks_to_draw = self._update_ticks()
#    1204 ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
#    1205                                                         renderer)
#    1207 for tick in ticks_to_draw:
#
# File /usr/lib/python3/dist-packages/matplotlib/axis.py:1079, in Axis._update_ticks(self)
#    1074 def _update_ticks(self):
#    1075     """
#    1076     Update ticks (position and labels) using the current data interval of
#    1077     the axes.  Return the list of ticks that will be drawn.
#    1078     """
# -> 1079     major_locs = self.get_majorticklocs()
#    1080     major_labels = self.major.formatter.format_ticks(major_locs)
#    1081     major_ticks = self.get_major_ticks(len(major_locs))
#
# File /usr/lib/python3/dist-packages/matplotlib/axis.py:1324, in Axis.get_majorticklocs(self)
#    1322 def get_majorticklocs(self):
#    1323     """Get the array of major tick locations in data coordinates."""
# -> 1324     return self.major.locator()
#
# File /usr/lib/python3/dist-packages/matplotlib/ticker.py:2081, in MaxNLocator.__call__(self)
#    2079 def __call__(self):
#    2080     vmin, vmax = self.axis.get_view_interval()
# -> 2081     return self.tick_values(vmin, vmax)
#
# File /usr/lib/python3/dist-packages/matplotlib/ticker.py:2089, in MaxNLocator.tick_values(self, vmin, vmax)
#    2086     vmin = -vmax
#    2087 vmin, vmax = mtransforms.nonsingular(
#    2088     vmin, vmax, expander=1e-13, tiny=1e-14)
# -> 2089 locs = self._raw_ticks(vmin, vmax)
#    2091 prune = self._prune
#    2092 if prune == 'lower':
#
# File /usr/lib/python3/dist-packages/matplotlib/ticker.py:2028, in MaxNLocator._raw_ticks(self, vmin, vmax)
#    2026 if self._nbins == 'auto':
#    2027     if self.axis is not None:
# -> 2028         nbins = np.clip(self.axis.get_tick_space(),
#    2029                         max(1, self._min_n_ticks - 1), 9)
#    2030     else:
#    2031         nbins = 9
#
# File /usr/lib/python3/dist-packages/matplotlib/axis.py:2491, in YAxis.get_tick_space(self)
#    2489 ends = self.axes.transAxes.transform([[0, 0], [0, 1]])
#    2490 length = ((ends[1][1] - ends[0][1]) / self.axes.figure.dpi) * 72
# -> 2491 tick = self._get_tick(True)
#    2492 # Having a spacing of at least 2 just looks good.
#    2493 size = tick.label1.get_size() * 2.0
#
# File /usr/lib/python3/dist-packages/matplotlib/axis.py:2223, in YAxis._get_tick(self, major)
#    2221 else:
#    2222     tick_kw = self._minor_tick_kw
# -> 2223 return YTick(self.axes, 0, '', major=major, **tick_kw)
#
# File /usr/lib/python3/dist-packages/matplotlib/axis.py:158, in Tick.__init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kw)
#     154 self._grid_kw = {k[5:]: v for k, v in kw.items()}
#     156 self.apply_tickdir(tickdir)
# --> 158 self.tick1line = self._get_tick1line()
#     159 self.tick2line = self._get_tick2line()
#     160 self.gridline = self._get_gridline()
#
# File /usr/lib/python3/dist-packages/matplotlib/axis.py:577, in YTick._get_tick1line(self)
#     574 'Get the default line2D instance'
#     575 # x in axes coords, y in data coords
# --> 577 l = mlines.Line2D((0,), (0,),
#     578                   color=self._color,
#     579                   marker=self._tickmarkers[0],
#     580                   linestyle='None',
#     581                   markersize=self._size,
#     582                   markeredgewidth=self._width,
#     583                   zorder=self._zorder)
#     584 l.set_transform(self.axes.get_yaxis_transform(which='tick1'))
#     585 self._set_artist_props(l)
#
# File /usr/lib/python3/dist-packages/matplotlib/lines.py:382, in Line2D.__init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     380 self._color = None
#     381 self.set_color(color)
# --> 382 self._marker = MarkerStyle(marker, fillstyle)
#     384 self._markevery = None
#     385 self._markersize = None
#
# File /usr/lib/python3/dist-packages/matplotlib/markers.py:243, in MarkerStyle.__init__(self, marker, fillstyle)
#     241 self._marker_function = None
#     242 self.set_fillstyle(fillstyle)
# --> 243 self.set_marker(marker)
#
# File /usr/lib/python3/dist-packages/matplotlib/markers.py:316, in MarkerStyle.set_marker(self, marker)
#     312         raise ValueError('Unrecognized marker style {!r}'
#     313                          .format(marker))
#     315 self._marker = marker
# --> 316 self._recache()
#
# File /usr/lib/python3/dist-packages/matplotlib/markers.py:256, in MarkerStyle._recache(self)
#     254 self._capstyle = 'butt'
#     255 self._filled = True
# --> 256 self._marker_function()
#
# File /usr/lib/python3/dist-packages/matplotlib/markers.py:749, in MarkerStyle._set_tickleft(self)
#     748 def _set_tickleft(self):
# --> 749     self._transform = Affine2D().scale(-1.0, 1.0)
#     750     self._snap_threshold = 1.0
#     751     self._filled = False
#
# KeyboardInterrupt:
