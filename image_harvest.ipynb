# %%
from robolab_turtlebot import Turtlebot, Rate
turtle = Turtlebot(rgb=True, depth=True, pc=True)
rate = Rate(10)

# %%
import matplotlib.pyplot as plt
import PIL
from IPython.display import clear_output

# %%
import time
for i in range(20):
    clear_output(True)
    img = turtle.get_rgb_image()
    plt.imshow(img)
    plt.show()
    plt.imsave(f"positive{i}.jpg", img)
    print(f"Saved positive{i}.jpg")
    time.sleep(5)
# Out:
# Saved positive18.jpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 9
#       7 plt.imsave(f"positive{i}.jpg", img)
#       8 print(f"Saved positive{i}.jpg")
# ----> 9 time.sleep(5)
#
# KeyboardInterrupt:
